# %%
from matplotlib import pyplot as plt

# %%
years = [1950, 1968, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title("Nominal GDP")
plt.ylabel("Billions of $")
plt.show()

# %%
movies = ["Annie Hall", "Ben-Hur", "Casblana", "Gandhi", "west Side Story"]
num_oscars = [5, 11, 3, 8, 10]
#so thast each bar is centered
xs = [i + 0.1 for i, _ in enumerate(movies)]

#plot bars with left x- coordinates
plt.bar(xs, num_oscars)

plt.ylabel("# of Academy Awards")
plt.title("My favorite Movies")
#label x - axis
plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from collections import Counter
grades = [84,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade // 10 * 10
histogram = Counter(decile(grade) for grade in grades)
plt.bar([x - 4 for x in histogram.keys()],
        histogram.values(),
        8)
plt.axis([-5, 105, 0 , 5])
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %%
mentions = [500, 505]
years = [2013, 2014]
plt.bar([2012.6, 2013.6], mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard that someones say 'data science'")

plt.ticklabel_format(useOffset=False)

plt.axis([2012.5,2014.5,499,506])
plt.title("Look at the 'Huge' Increase!")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.axis([2012.5,2014.5,0,550])
plt.title("Not So huge Anymore")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance,   'g-', label ='variance')
plt.plot(xs, bias_squared, 'r-.', label ='bias^2')
plt.plot(xs, total_error, 'b:', label ='total error')

plt.legend(loc=9)
plt.xlabel("model complexity")
plt.title("The BIas-Variance Tradeoff")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
friends = [ 70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
        xy = (friend_count, minute_count),
        xytext=(5, -5), 
        textcoords='offset points')
plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")
plt.show()

# %%
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.title("Axes Aren't Comparable")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")
plt.show()

# %%
#pg. 49
height_weight_age = [70,
                    170,
                    40 ]
grades = [95,
          80,
          75,
          62]
#pg 50 vectors 
def vector_add(v, w):
    return [v_i, w_i in zip(v, w)]
def vector_subtract(v, w):
    return [v_i - w_i
            for v_i, w_i in zip(v, w)]
def vector_sum(vectors):
    result = vectors[0]
    for vector in vectors[:1]:
        result = vector_add(result, vector)
    return result
#pg 51
def vector_sum(vectors):
    return reduce(vector_add, vectors)
def scalar_multiply(c, v):
    return [c * v_i for v_i in v]
def vector_mean(vectors):
    n = len(vectors)
    return scalar_multiply(1/n, vector_sum(vectors))
def dot(v, w):
    return sum(v_i * w_i
                for v_i, w_i in zip(v,w))
    return result
def squared_distance(v, w):
    return sum_of_squares(vector_subtract(v,w))
def distance(v,w):
    return math.sqrt(squared_distance(v, w))
#pg. 53 matrices
A = [[1, 2, 3],
     [4, 5, 6]]
B = [[1, 2],
     [3, 4],
     [5, 6]]
def shape(A):
    num_rows = len(A)
    num_cols = len(A[0]) if A else 0
    return num_rows, num_cols
def get_row(A, i):
    return A[i]
def get_column(A, j):
    return [A_i[j]
            for A_i in A]
def make_matrix(num_rows, num_cols, entry_fn):
        
        return [[entry_fn(i, j)
            for j in range(num_cols)]
            for i in range(num_rows)]
def is_diagonal(i,j):
    return 1 if i == j else 0

# %%
#describgin a single set of data 
#pg 58 top
friend_counts = Counter(num_friends)
xs = range(101)
ys = [friend_counts [x] for x in xs]
plt.bar(xs, ys)
plt.axis([0, 101, 0, 25])
plt.title("Histogram of friend Counts")
plt.xlabel("#of Friends")
plt.ylabel("#of people")
plt.show
#number of points #pg 59
num_points = len(num_friends)
largest_value = max(num_friends)
smallest_value = min(num_friends)
sorted_values = sorted(num_friends)
smallest value = sorted_values[0]
second_smallest_value = sorted_value[1]
second_largest_value = sorted_values[-2]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-19-5132e8798ecf> in <module>()
# ----> 1 friend_counts = Counter(num_friends)
#       2 xs = range(101)
#       3 ys = [friend_counts [x] for x in xs]
#       4 plt.bar(xs, ys)
#       5 plt.axis([0, 101, 0, 25])
#
# NameError: name 'num_friends' is not defined

# %%
#central tendencies pg 59, single data set
#this isnt right if you dont __future__ import division
def mean(x):
    return sum(x) / len(x)
mean(num_friends)
def median(v):
    n = len(v)
    sorted_v = sorted(v)
    midpoint = n // 2
     if n % 2 == 1:  #odd
        return sprted_v[midpoint]
     else:
         lo = midpoint - 1
         hi = midpoint
         return (sorted_v[lo] + sorted_v[hi]) / 2
         median(num_friends) 
#quantile
def quantile(x, p):
    p_index = int(p * len(x))
    return sorted(x)[p_index]
quantile(num_friends, 0.10)
quantile(num_friends, 0.25)
quantile(num_friednds, 0.75)
quantile(num_friends, 0.90)

#pd. 61 dispersion
def data_range(x):
    return max(x) - min(x)
data_range(num_friends)

def de_mean(x):
    x_bar = mean(x)
    return [x_i - x_bar for x_i in x]
def variance(x):
    n = len(x)
    deviations = de_mean(x)
    return sum_of_squares(deviations) / (n-1)
variance(num_friends)

# %%
#Chapter 6 sums up dependence and independence
#pg. 71 conditional probability 
def random_kid():
    return random.choice(["boy", "girl"])
both_girls = 0
older_girl = 0
either_girl = 0

random.seed(0)
for _ in range(10000):
    younger = random_kid()
    older = randome_kid()
    if older == "girl":
        older += 1
    if older == "girl" and younger == "girl":
        both_girls += 1
    if older == "girl" or younger == "girl":
        either_girl += 1
print "P(both | older):", both_girls / older_girl #0.514 ~ 1/2
print "P(both | either): ", both_girls / either_girl

# %%
#Continuos Distributions
#random variables is on pg 73 and Bayes's theorem is 72
#pg. 74
def uniform_pdf(x):
    return 1 if x >= 0 and x < 1 else 0
def uniform_cdf(x):
    if x < 0: return 0
    elif x < 1: return x
    else: return 1

# %%
#pg 76
#varios Normal Distribution pdfs
def normal_pdf(x, mu=0, sigma=1):
    sqrt_two_pi = math.sqrt(2 * math.pi)
    return (math.exp(-(x-mu) ** 2 / 2 / sigma ** 2) / (sqrt_two_pi * sigma))
xs = [x / 10.0 for x in range (-50, 50)]
plt.plot(xs,[normal_pdf(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
plt.plot(xs,[normal_pdf(x,sigma=2) for x in xs],' -- ', label='mu=0,sigma=2' )
plt.plot(xs,[normal_pdf(x,sigma=0.5) for x in xs],':',label='mu=0,sigma=0.5')
plt.plot(xs,[normal_pdf(x,mu=-1) for x in xs], '-.',label='mu-1,sigma=1')
plt.legend()
plt.title("Various Normal pdfs")
plt.show

# %%
#pg 77 
#The Normal Distribution various cdfs
def normal_cdf(x, mu=0, sigma=1):
    return (1 + math.erf((x - mu) / math.sqrt(2) / sigma)) / 2
xs = [x / 10.0 for x in range (-50, 50)]
plt.plot(xs,[normal_cdf(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
plt.plot(xs,[normal_cdf(x,sigma=2) for x in xs],' -- ', label='mu=0,sigma=2' )
plt.plot(xs,[normal_cdf(x,sigma=0.5) for x in xs],':',label='mu=0,sigma=0.5')
plt.plot(xs,[normal_cdf(x,mu=-1) for x in xs], '-.',label='mu-1,sigma=1')
plt.legend(loc=4)
plt.title("Various Normal cdfs")
plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-33-493a4060fe04> in <module>()
#       2     return (1 + math.erf((x - mu) / math.sqrt(2) / sigma)) / 2
#       3 xs = [x / 10.0 for x in range (-50, 50)]
# ----> 4 plt.plot(xs,[normal_cdf(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
#       5 plt.plot(xs,[normal_cdf(x,sigma=2) for x in xs],' -- ', label='mu=0,sigma=2' )
#       6 plt.plot(xs,[normal_cdf(x,sigma=0.5) for x in xs],':',label='mu=0,sigma=0.5')
#
# <ipython-input-33-493a4060fe04> in normal_cdf(x, mu, sigma)
#       1 def normal_cdf(x, mu=0, sigma=1):
# ----> 2     return (1 + math.erf((x - mu) / math.sqrt(2) / sigma)) / 2
#       3 xs = [x / 10.0 for x in range (-50, 50)]
#       4 plt.plot(xs,[normal_cdf(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
#       5 plt.plot(xs,[normal_cdf(x,sigma=2) for x in xs],' -- ', label='mu=0,sigma=2' )
#
# NameError: global name 'math' is not defined

# %%
#The central limit Thereom
#pg 78
def bernoulli_trial(p):
    return 1 if random.random() < p else 0

def binomial(n,p):
    return sum(bernoulli_trial(p) for _ in range (n))
def make_hist(p, n, num_points):
    
    data = [binomial(n, p) for _ in range (num_points)]
    
    histogram = Counter(data)
    plt.bar([x - 0.4 for x in histogram keys()]
            [v / num_points for v in histogram.values()],
            0.8,
            color='0.75')
    mu = p * n
    sigma = math.sqrt(n * p * (1 -p))
    
    # use a line chart to show the normal approximation
    xs = range(min(data), max(data) + 1)
    ys = [normal_cdf(i + 0.5, mu, sigma) - normal_cdf(i - 0.5, mu, sigma)
          for i in xs]
    plt.plot(xs,ys)
    plt.title("Binomial Distribution vs. Normal Approxximation")
    plt.show()

# %%
def two_sided_p_value(x, mu=0, sigma=1):
    if x >= mu:
        return 2 * normal_probability_above(x, mu, sigma)
    else:
        return 2 * normal_probability_below(x, mu, sigma)
two_sided_p_values(529.5, mu_0, sigma_0)

# %%
extreme_value_count = 0
for _ in range(100000):
    num_heads = sum(1 if random.random() < 0.5 else 0
                    for _ in range (1000))
if num_heads >= 530 or num_heads <= 470:
    extreme_value_count += 1
print extreme_value_counts / 100000
#p values

# %%
#confidence interval
#looking at the coin flip  fo the average of the bernouilli variabvles corresponding to each flip
math.sqrt(p * (1 - p) / 1000)
mu = p_hat
sigma = math.sqrt(p_hat * (1 - p_hat) / 1000)

# %%
#pg 86-87
#p-hacking
def run_experiment():
    return [random.random() < 0.5 for _ in range(1000)]
def reject_fairness(experiment):
    num_heads = len([flip for flip in experiment if flip])
    return num_heads < 469 for num_heads > 531
random.seed(0)
experiments = [run_experiment() for _ in range(1000)]
num_rejections = len([experiment
                     for experiment in experiments
                     if rejec_fairness(experiment)])

print num_rejections

# %%
#experience optimization 
#A/B test, WHICH IS BETTER ! with Bernoulli trial

def estimated_parameters(N, n):
    p = n / N
    sigma = math.sqrt(p * (1 - p) / N)
    return p, sigma
def a_b_test_statistic(N_A, n_A, N_B, n_B):
    p_A, sigma_A = estimated_parameters(N_A, n_A)
    p_B, sigma_B = estimated_parameters(N_B, n_B)
    return (p+B - p_A) / math.sqrt(sigma_A ** 2 + sigma_B ** 2)
#on completion of trial be sure to run that stitistical test #pg 88

# %%
##Bayseian Inference
#pg.89
def B(alpha, beta):
    return math.ganna(alpha) * math.gamma(beta) / math.gamma(alpha + beta)
def beta_pdf(x, alpha, beta):
    if x <= 0 or x >= 1:  #no weight outside of [0,1]
        return 0
    return x ** (alpha - 1) * (1 - x) ** (beta - 1) / B(alpha, beta)

# %%
#pg 93-96(top) The idea behind gradietn descent/ Estimating the Gradient
def sum_of_squares(v):
    return sum(v_i ** 2 for v_i in v)
def difference_quotient(f, x, h):
    return (f(x + h) - f(x)) / h
def square(x):
    return x * x
def derivative(x):
    return 2* x
derivative_estimate = partial(difference_quotient, square, h=0.00001)

# %%
#pg 96 top Estimating the gradient
import matplotlib.pyplot as plt
x = range(-10, 10)
plt.title("Actual Derivatives vs. Estimates")
plt.plot(x, map(derivative, x), 'rx', label='Actual')
plt.plot(x, map(derivative_estimate, x), 'b+', label='Estimate')
plt.legend(loc=9)

plt.show()
def partial_difference_quotient(f, v, i, h):
    w = [v_j + (h if j ==i else 0)
        for j, v_j in enumerate(v)]
    return (f(w) - f(v)) / h
def estimate_gradient(f, v, h=0.00001):
    return [partial_difference_quotient(f, v, i, h)
           for i, _ in enumerate(v)]

# %%
#pg 97, Using the Gradient
def step(v, direction, step_size):
    return [v_i, direction_i in zip(v, direction)
            for v_i, direction_i for i in range(3)]
def sum_of_squares_gradient(v):
    return [2 * v_i for v_i in v]

v = [random.randint(-10,10) for i in range(3)]

tolerance = 0.0000001

while True:
    gradient = sum_of_squares_gradient(v)
    next_v = step(v, gradient, -0.01)
        break
    v = next_v

# %%
#pg. 98 middleChoosing the right step Size
step_sizes = [100, 10 , 1, 0.1, 0.01, 0.001, 0.0001, 0.00001]
def safe(f):
    def safe_f(*args, **kwargs):
        try: 
            return f(*args, **kwargs)
        except:
            return float('inf')
    return safe_f

# %%
#pg 98 putting it all together
def minimize_batch(target_fn, gradient_fn, theta_0, tolerance=0.000001):
    step_sizes = [100, 10 , 1, 0.1, 0.01, 0.001, 0.0001, 0.00001]
    theta = theta_0
    target_fn = safe(target_fn)
    value = target_fn(theta)
    while True:
        gradient = gradient_fn(theta)
        next_thetas = [step(theta, gradient, -step_size)
                      for step_size in step_sizes]
        next_theta = min(next_thetas, key=target_fn)
        next_value = target_fn(next_theta)
        
        if abs(value - next_value) < tolerance:
            return theta
        else:
            theta, value, = next_theta, next_value
def negate(f):
    return lambda *args, **kwargs: -f(*args, **kwargs)

def negate_all(f):
        return lambda *args, **kwargs: [-y for y in f(*args, **kwargs)]

def maximize_batch(target_fn, gradient_fn, theta_0, tolerance=0.000001):
    return minimize_batch(negate(target_fn),
                          negate_all(gradient_fn),
                          theta_0,
                          tolerance)

# %%
# %matplot inline
#page 99 stochastic gradient descent
def in_random_order(data):
    indexes = [i for i, _ in enumerate(data)]
    random.shuffle(indexes)
    for i in indexes:
        yield data[i]
def minimize_stochastic(target_fn, gradient_fn, x, y, theta_0, alpha_0=0.01):
    
    data = zip(x, y)
    theta = theta_0
    alpha = alpha_0
    min_teta, min_value = None, float("inf")
    iterations_with_no_improvement = 0
    
    while iterations_with_no_improvement < 100:
        value = sum( target_fn(x_i, y_i, theta) for x_i, y_i in data )
        
        if value < min_value:
            min_theta, min_value = theta, value
            iterations_with_no_imporvement = 0
            alpha = alpha_0
        
        else:
            iterations_with_no_imporvement += 1
            alpha *= 0.9
            
        for x_i, y_i in in_random_order(data):
            gradient_i = gradient_fn(x_i, y_i, theta)
            theta = vector_subtract(theta, scalar_multiply(alpha, gradient_i))
        return min_theta

# %%
#pg 100
def maximize_stochastic(target_fn, gradietn_fn, x, y, theta_0, alpha_0=0.01):
    return minimize_stochastic(negative(target_fn),
                                negate_all(gradient_fn),
                                  x, y, theta_0, alpha_0)

# %%
#pg 103
#stdin and stout
#egrep.py
import sys, re
#sys.argv is the lsit of commnad-line arguments
#sys.argv[0] is the name of the program itself
#sys.argv[1] willl be the regex specified at the command line
regex = sys.argv[1]

# for every line passed intp the script
for line in sys.stdin:
    #if it matches the regex, write to stdout
    if re.search(regex, line):
        sys.stdout.write(line)
#line_count.py
import sys

count = 0
for line in sys.stdin:
    count += 1
#print goes to sys.stdout
print count

type SomeFile.txt | python egrep.py "[0-9]" | python line_count.py

# %%
# 'r' means read-only
file_for_reading = open('reading_file.text', 'r')

# 'w' is for write, will destroy the file if it already exists
file_for_writing = open('appending_file.txt', 'a')

#'a' is append -- for adding ot the ned of the file
file_for_appending = open('appending_file.txt', 'a')

#don't forget to close your ifles when you are done
file_for_writing.close()

# %%
#a script that counts the most comon words in python
#most_common_words.py
#pg 104 middle
import_sys
from collection import Counter

# pass in number of words as first argument
try:
    num_words = int(sys.argv[1])
except:
    print "usage: most_common_words.py num_words"
    sys.exit(1) # non-zero exit code indicates error
count = Counter(word.lower()
                for line in sys.stdin
                for word in line.strip().split()
                if word)
for word, count in counter.most_common(num_words):
    sys.stdout.wrtie(str(count))
    sys.stdout.wrtie("\t")
    sys.stdout.write(word)
    sys.stdout.write("\n")

# %%
#another way to close is ot add a block
#bottom pg 105 Basic text files
with open(filename, 'r') as f:
   data = function_that_gets_data_from(f)
#at this point f has already been closed so dont try to use it
process(data)

#if you need to write a whole text file
#iterate over the lines of the file using
for:
    starts_with_hash = 0
    
    with open('input.txt', 'r') as f:
        for line in f:
            if re.mathc("^#", line):
                starts_with_hash += 1
#starts with a new line characted you might want ssto strip()
def get_domain(email_address):
    return email_address.lower().split("@")[-1]
with open('email_addresses.txt', 'r') s f:
    domain_counts = Counter(get_domain(line.strip())
                            for line in f 
                            if "@" in line)

# %%
#for things without a header jsut stats and information like date
#pg 107 Delimited files
import csv
with open('tab_delimited_stock_prices.txt', 'rb') as f:
    reader = csv.reader(f, delimiter'\t')
    for row in reader:
        date = row[0]
        symbol = row[1]
        closing_price = float(row[2])
        process(date, symbol, closing_price)
        
#if your data has a header row
with open('colon_delimited_stocks_prices.txt, 'rb') as f:
    reader = csv.DictReader(f, delimiter=':')
    for row in reader:
          date = row["date"]
          symbol = rpw["symbol"]
          closing_price = flaot(row["closing_price"])
          process(date, symbol, closing_price)
    #even if it doesnt have headers you can still use DictReader by passing keys as a fieldnames parameter
todays_price = { 'AAPL' : 90.92, 'MSFT' : 41.68, 'FB' : 64.5}
with open('comma_delimited_stock_prices.txt', 'wb') as f:
    writer = csv.writer(f, delimiter=',')
    for stock, price in today_prices.items():
          writer.wrtirerow([stock, price])
          #csv will do the right thing if your valuses are eseperated by commas

# %%
#pg 109
from bs4 import BeautifulSoup
import request
html = requests.get("http://www.example.com").text
soup = BeautifulSoup(html, 'html5lib')
first_paragraph = soup.find('p')
first_paragraph_text = soup.p.text
first_paragraph_words = soup.p.text.split()
first paragraph_id = soup.p['id']
first_paragraph_id2 = soup.p.get('id')
    all_paragraphs = soup.find_all('p')
    paragraphs_with_ids = [p for p in soup('p') if p.get('id')]
    important_paragraphs = soup('p', {'class' : 'important'})
    important_paragraphs2 = soup('p', 'important')
    important_paragraph3 = [p for p in soup('p')
                            if 'important' in p.get('class' [])]
# Out:
#   File "<ipython-input-21-9101f6fcdc35>", line 8
#     first paragraph_id = soup.p['id']
#                      ^
# SyntaxError: invalid syntax

# %%
#pg 109 scarping the web
#pg 111 top
from bs4 import BeautifulSoap
import request
url = "http://shop.oreilly.com/category/browse-subjects/" + \
      "data.do?sortby=publicationData&page=1"
soup = BeautifulSoup(requests.get(url).text, 'html5lib')

# %%
#bottom pg 111 Oreilly book example, getting data web scarping
def is_video(td):
    pricelabels = td('span', 'pricelabel')
    return (len(pricelabels) == 1 and
       pricelabels[0].text.strip().startswith("Video")) 
print len([td for td in tds if not is_viedeo(td)])
title = td.find("div", "thumbreader").a.text
author_name = td.find('div', 'AuthorName').text
authors = [x.strip() for x in re.sub("^By ", "", author_name).split(",")]
isbn_link = td.find("div", "thumbheader").a.get("href")

# re.match captures the part of the regex in parantheses
isbn = re.match("/product/(.*)\.do", isbn_link).group(1)

date = td.find("span", "directorydate").text.strip()

def book_info(td):
    title = td.find("div", "thumbheader").a.text
    by_author = td.find('div', 'AuthorName').text
    authors = [x.strip() for x in re.sub("^By", "", by_author).split(".")]
    isbn_link = td.find("div", "thumbheader").a.get("href")
    isbn = re.match("/product/(.*)\.de", isbn_link).groups()[0]
    date = td.find("span", "directorydate").text.strip()
                                                    
    return {
        "title" : title,
        "author" : authors,
        "isbn" : isbn,
        "date" : date
    }
from bs4 import BeautifulSoup
import requests
from time import sleep
base_url = "http://shop.oreilly.com/category/browse-subject/" + \
           "data.do?sortby=publicationDAte&page="
books = []
NUM_PAGES = 31

for page_num in range(1, NUM_PAGES + 1):
    print "soup in page", page_num, ",", len(books), " found so far"
    url = base_url + str(page_num)
    soup = BeautifulSoup(requests.get(url).text, 'html5lib')
    for td in soup('td', 'thumbtext'):
        if not is_video(td):
           books.append(book_info(td))
sleep(30)

# %%
#pg 113 getting data 
def get_year(book):
    return int(book["date"].split()[1])

year_counts = Counter(get_year(book) for book in books
                     if get_year(book) <= 2014)

import matplotlib.pyplot as plt
years = sorted(year_counts)
book_counts = [year_counts[year] for year in years]
plt.plot(years, book_counts)
plt.ylabel("# of data books")
plt.title("Data is Big!")
plt.show

# %%
#pg 114 JSON and XML
{ "title" : "Data Science Book",
  "author" : "Joel Grus",
  "publicationYear" : 2014,
  "topics" : [ "data", "science", "data science"]}
import json
serialized = """{ "title" : "Data Science Book",
  "author" : "Joel Grus",
  "publicationYear" : 2014,
  "topics" : [ "data", "science", "data science"]}"""
deserialized = json.loads(serialized)
if "data science" in deserialized["topics"]:
    print deserialized

# %%
#pg 118 getting data
from twython import Twython
twitter = Twython(CONSUNMER_KEY, CONSUMER_SECRET)
#search for tweets containing the phrase "data science"

for status in twitter.search(q='"data science"')["statuses"]:
    user = status["user"]["screen_name"].encode('utf-8')
    text = status["text"].encode('utf-8')
    print user, ":" , text
    print
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-24-14b85c77f51c> in <module>()
# ----> 1 from twython import Twython
#       2 twitter = Twython(CONSUNMER_KEY, CONSUMER_SECRET)
#       3 #search for tweets containing the phrase "data science"
#       4
#       5 for status in twitter.search(q='"data science"')["statuses"]:
#
# ImportError: No module named twython

# %%
#122 working with data
def bucketize(point, bucket_size):
    return bucket_size * math.floor(point / bucketsize)

def make_histogram(points, bucket_size):
    return Counter(bucketize(point, bucket_size) for point in points)

def plot_histogram(points, bucket_size, title=""):
    histogram = make_histogram(points, bucket_size)
    plt.bar(histogram.keys(), histogram.values(), width=bucket_size)
    plt.title(title)
    plt.show()

# %%
#pg 122 very cloes means
random.seed(0)
uniform = [200 * random.random() - 100 for _ in range (10000)]

normal = [57 * inverse_normal_cdf(random.random())
         for _ in range(10000)]
plot_histogram(uniform, 10, "Uniform Histogram")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-30-23f7e063d9d0> in <module>()
# ----> 1 random.seed(0)
#       2 uniform = [200 * random.random() - 100 for _ in range (10000)]
#       3
#       4 normal = [57 * inverse_normal_cdf(random.random())
#       5          for _ in range(10000)]
#
# NameError: name 'random' is not defined

# %%
#page 124 scatter plot
de random_normal():
    return inverse_normal_cdf(random.random())
plt.scatter(xs, ys1, marker='.', color='black', label='ys1')
plt.scatter(xs, ys2, marker='.', color='gray', label='ys2')
plt.xlabel('xs')
plt.ylabel('ys')
plt.legend(loc=9)
plt.title("Very Different Joint Distributions")
plt.show
print correlations(xs, ys1)
print correlations(xs, ys2)
# Out:
#   File "<ipython-input-34-ad59d0920e31>", line 2
#     de random_normal():
#                    ^
# SyntaxError: invalid syntax

# %%
#pg 125 Many dimensions
def correlation_matrix(data):
    _, num_columns_matrix(data):
    def matrix_entry(i, j):
        return correlation(get_column(data, i) get_column(data,j))
    return make_matrix(num_columns, num_columns, matrix_entry)
import matplotlib.pyplot as plt
_, num_columns = shape(data)
fig, ax = plt.subplots(num_columns, num_columns)

for i in range(num_columns):
    for j in range(num_columns):
        
        #scatter column j on x and column on y axis
        if i != j: ax[i][j].scatter(get_column(data,j), get_column(data, i))
            
        #unles i = j then show the serires name
        else: ax[i][j].annotate("series " + str(i), (0.5, 0.5),
                               xycoords='axes fraction',
                               ha="center", va="center")
        #fix the bottom right and top left acis labels
        ax[-1][-1].set_xlim(ax[0][-1].get_xlm())
        ax[0][0].set_ylim(ax[0][1].get_ylim())
        
        plt.show
# Out:
#   File "<ipython-input-36-5709b895cb00>", line 3
#     _, num_columns_matrix(data):
#                                ^
# SyntaxError: invalid syntax

# %%
#pg 127 cleaning and munging data that is dirty
def parse_row(input_row, parsers):
    return [parser(value) if parser is None else value
            for value, parser in zip(input_row, parsers)]
def parse_rows+with(reader, parsers):
    yield parse_row(row, parsers)
#use if the float is not an actual number representation
    
def try_or_none(f):
    def f_or_none(x):
        try: return f(x)
        except: return None
    return f_or_none
def parse_row(input_row, parsers):
    return [try_or_none(parser)(value) if parser is not Non else value
            for value, parser in zip(input_row, parsers)]

#if we have comma-delimited stock prices with bad data:
import dateutil.parser
data = []

with open("comma_delimited_stock_prices.csv", "rb") as f:
    reader = csv.reader(f)
    for line in parse_rows_with(reader, [dateutil.parser.parse, None, float]):
        data.append(line)
    for row in data:
        if any(x is None for x in row)
           print row
def try_parse_field(field_name, value, parser_dict):
    parser = parser_dict.get(field_name)
    if parser is not None:
        return try_or_none(parser)(value)
    else:
        return value
    
def parse_dict(input_dict, parser_dict):
    return { field_name : try_parse_field(field_name, value, parser_dict)
             for field_name, value in input_dict.iteritems() }

# %%
#manipulating Data pg 129
data = [
    {'closing_price': 102.06,
     'date': datetime.datetime(2014, 8, 29, 0, 0),
     'symbol': 'AAPL'},
    # ... 
]
#if this is the type of data recieved 1. respect to AAPL rows, grab closing_price from each row, take the max of those prices
max_apple_price = max(row["closing_price"]
                     for row in data
                     if row["symbol"] == "APL")
#we would still nede the stock highest ever clsoing price. 1. group together all rows with the same symbol, do same before each
#droup rows by symbol
by_symbol = defaultdict(list)
for row in data:
    by_symbol[row["symbol"]].append(row)

#use dict comprehesion to find the max for each symbol
max_price_by_symbol = {symbol : max(row["closing_price"]
                                   for row in grouped_rows)
                      for symbol, grouped_rows in by_symbol.iteritems() }
def picker(field_name):
    return lambda row: row[field_name]
def pluck(field_name, rows):
    return map(picker(field_name), rows)
#grouper value_transform
def group_by(grouper, rows, value, transform = None):
    grouped = defaultdict(list)
    for rows in rows:
        grouped[grouper(row)].append(row)
        
    if value_transform is None:
        return grouped
    else:
        return { key : value_transform(rows)
                 for key, rows in grouped.iteritems() }
    max_price_by_symbol = group_by(picker("symbol"),
                                  data,
                                  lambda rows max(pluck("closing_price", rows)))
#more goruping by symbol
#1 order prices by date 2. use zip to get pairs(previous current) 3 turn the pairs in to new percent change rows

def percent_price_change(yesterday, today):
    return today["closing_price" / yesterday["closing_price"] - 1]
def day_over_day_changes(grouped_rows):
    ordered = sorted(grouped_rows, key=picker("data"))
    
    return [{ "symbol" : today["symbol"],
              "date" : today["date"],
              "change" : percent_price_change(yesterday, today) }
           for yesterday, today in zip(ordered, ordered[1:])]
#use this as the cvalue transform 
changes_by_symbol = group_by(picker("symbol"), data, day_over_day_changes)

all_changes = [change
              for change in changes_by_symbol.values()
              for change in changes]
max(all_changes, key=picker("change"))
min(all_changes, keypciker("change"))

def combine_pct_changes(pct_change1, pct_change2):
    return (1 + pct_change1) * (1 + pct_change2) - 1
def overall_change(changes):
    return reduce(combine_pct_changes, pluck("change", changes))

overall_change_by_month = group_by(lambda row: row['date'].month,
                                  all_changes,
                                  overall_change)

# %%
#predictive modeling / data mining
#overfitting and underfitting, the solution is to test the model, possibly by splitin it in two
def split_data(data, prob):
    results = [], []
    for row in data:
    return results
def train_test_split(x, y, test_pct):
    data = zip(x, y)
    train, test = split_data(data, 1 - test_pct)
    x_train, y_train = zip(*train)
    x_test, y_test = xip(*test)
    return x_train, x_test, y_train, y_test
model = someKingOfModel()
x_train, x_test, y_train, y_test = train_test_splits(xs, ys, 0.33)
model.train(x_train, y_train)
performance = model.test(x_test, y_test)
#if model is overfit it would not work on a smaller data set because it was over fit for the initialmodel
#but using the split test to evaluate if the test works is not a way
#maybe split in to three tests and see if it is identifying the final model

# %%
#146 compute performance accuracy
def accuracy (tp, fp, fn , tn):
    correct = tp + tn
    total = tp + fp + fn + tn
    return correct / total

print accuracy(70, 4930, 13930, 981070)
#for the specific test

def precision(tp, fp, fn, tn):
    return tp / (tp + fn)

print recall(70, 4930, 13930, 981070)

def recall(tp, fp, fn, tn):
    return tp / (tp + fn)

print recall(70, 4930, 13930, 981070)

def f1_score(tp, fp, fn, tn):
    p = precision(tp, fp, fn, tn)
    r = recall(tp, fp, fn, tn)
    
    return 2 * p * r / (p + r)
#Naive Bayes, yes-or no
# Regression models numeric features, could include dummy variable 0s and 1s
#decision tress can deal with numeric categorical data
#dimensionality reduction if reducing inforamtion predit better, or Regularization to penalize some feature
# Out:
#   File "<ipython-input-38-636c676ddb79>", line 20
#     def f1_score(tp, fp, fn, tn)
#                                 ^
# SyntaxError: invalid syntax

# %%
#pg 151 K nearest neighbours
def raw_majority_votes(labels):
    votes = Counter(labels)
    winner, _= votes.most_common(1)[0]
    return winner
def majority_voter(labels):
    votes_counts = Counter(labels)
    winner, winner_cont = vote_counts.most_common(1)[0]
    num_winners = len([count
                      for count in vote_counts.values()
                      if count == winner_counts])
    if num_winners == 1:
        return winner
    else:
        return majorit_vote(labels[:-1])
def knn_classify(k, labeled_points, new_point):
    by_distance = sorted(labeled_points,
                        key=lambda (point, _): distance(point, new_point))
    k_nearest_labels = [label for _, label in by_distance[:k]]
    
    return majority_vote(k_nearest_labels)

#example

cities = [([-122.3, 47.52], "Python"),
          ([-96.85, 32.85], "Java"),
          ([-89.33, 43.13], "R")]
#plot the data
plots = { "Java" : ([], []), "Python" : ([], []), "R" : ([], []) }
markers = { "Java" : "o", "Python" : "s", "R" : "^"}
colors  = { "Java" : "r", "Python" : "b", "R" : "g"}

for (longitude, latitude), language in cities:
    plots[language][0].append(longitude)
    plots[language][1].append(latitude)
#create a scatter plot for each language
for language, (x, y) in plots.iteritems():
    plt.scatter(x, y, color=colors[language], marker=markers[language],
                                               label=language, zorder=10)
    plot_state_borders(plt)
    plt.legend(loc=0)
    plt.axis([-130,-60,20,55])
    
    plt.title("Favorite Programming Languages")
    plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-42-09bd77dfbc59> in <module>()
#      38     plt.scatter(x, y, color=colors[language], marker=markers[language],
#      39                                                label=language, zorder=10)
# ---> 40     plot_state_borders(plt)
#      41     plt.legend(loc=0)
#      42     plt.axis([-130,-60,20,55])
#
# NameError: name 'plot_state_borders' is not defined

# %%
for k in [1, 3, 5, 7]:
    num_correct = 0
    
    for city in cities:
        location, actual_language = city
        other_cities = [other_city
                       for other_city in cities
                       if other_city != city]
        predict_language == actual_language:
            num_correct += 1
    print k, "neighbor[s]:", num_correct, "correct out of", len(cities)
    
for longitude in range(-130, -60):
    for latitude in range(20, 55):
        predicted_language = knn_classify(k, cities, [longitude, latitude])
        plots[predicted_language][0].append(longitude)
        plots[predicted_language][1].append(latitude)
        #curse of higher dimensionality, sicne higher dimnesions happen to be closer to each other.
#generate random poitns
def random_points(dim):
    return [distance(random_points(dim), random_point(dim))
           for _ in range(num_pairs)]
#for every dimensions we will compute 10,000 distances and use those to compute the average
dimensions = range(1, 101)
avg_distances = []
min_distances = []

random.seed(0)
for dim in dimensions:
    distances = random_distances(dim, 10000)
    avg_distances.append(mean(distances))
    min_distances.append(min(distances))
    #average distance increases to down the inbetween points
min_avg_ratio = [min_dist / avg_dist
                for min_dist, avg_dist in zip(min_distances, avg_distances)]
# Out:
#   File "<ipython-input-44-6e1956845837>", line 9
#     predict_language == actual_language:
#                                        ^
# SyntaxError: invalid syntax

# %%
def tokenize(message):
    message = message.lower()
    all_words = re.findall("[a-z0-9']+", message)
    return set(all_words)
def count_words(training_set):
    count = defaultdict(lambda: [0, 0])
    for message, is_spam in training_set:
        for word in tokenize(message):
            counts[word][0 if is_spam else 1] += 1
    return counts
def word_probabilities(counts, total_spams, total_non_spams, k=0.5):
    return [(w,
            (spam + k) / (total_spams + 2 * k),
            (non_spam + k) / (total_non_spams + 2 * k))
           for w, (spam, non_spam) in counts.iteriterms()]
def spam_probability(word_probs, message):
    message_words = tokenize(message)
    log_prob_if_spam = log_prob_if_not_spam in word_probs:
        if word in message_words
        log_prob_if_spam += math.log(prob_if_spam)
        log_prob_if_not_spam += math.log(prob_if_not_spam)
        
        else:
            log_prob_if_spam += math.log(1.0 - prob_if_spam)
            log_prob_if_not_spam += math.log(1.0 - prob_if_not_spam)
            
    prob_if_spam = math.exp(log_prob_if_spam)
    prob_if_not_spam = math.exp(log_prob_if_not_spam)
    return prob_if_spam / (prob_if_spam + prob_if_not_spam)

#pull together in naive bayes classifier
class NaiveBayesClassifier:
    def__init__(self, k=0.5):
        self.k = k
        self.word_probs = []
        
    def train(self, training_set):
        
        num_spams = len([is_spam
                        for message, is_spam in training_set
                        if is_spam])
        num_non_spams = len(training_set) - num_spams
        
        word_counts = count_words(training_set)
        self.word_probs = word_probabilities(word_counts,
                                            num_spams,
                                            num_non_spams,
                                            self.k)
    def classify(self, message):
        return spam_probability(self.word_probs, message)

# %%
#pg 170
import glob, re
path = r"C:\spam\*\*"

data = []
for fn in glob.glob(path):
    is_spam = "ham" not in fn
    
    with open(fn, 'r') as file:
        for line in file:
            if line.startswith("Subject:"):
                subject = re.sub(r"^Subject: ", "", line).strip()
                data.append((subject, is_spam))
                #split data in to training and test data
random.seed(0)
train_data, test_data = split_data(data, 0.75)

classifier = NaiveBayesClassifier()
classifier.train(train_data)

classified = [(subject, is_spam, classifier.classify(subject))
             for subject, is_spam in test_data]
coutns = Counter((is_spam, spam+probability > 0.5
                 for _, is_spam, spam_probability in classfield)
classified.sort(key=lamda row: row[2])
spammiest_hams = filter(lambda row: not row[1], classified)[-5:]
hammiest_spams = filter(lambda row: row[1], classified[:5])
                 
def p_spam_given_word(word_prob):
                 word, prob_if_spam, prob_if_bot_spam = word_prob
                 return prob_if_spam / (prob_if_spam + prob_if_not_spam)
words = sorted(classifier.word_probs, key=p_spam_given_word)
spammiest_words = words[-5:]
hammiest_words = words[:5]
